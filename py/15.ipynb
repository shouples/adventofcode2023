# %% [markdown]
# # Day 15
#
# ## Part 1
#
# The newly-focused parabolic reflector dish is sending all of the collected light to a point on the side of yet another mountain - the largest mountain on Lava Island. As you approach the mountain, you find that the light is being collected by the wall of a large facility embedded in the mountainside.
#
# You find a door under a large sign that says "Lava Production Facility" and next to a smaller sign that says "Danger - Personal Protective Equipment required beyond this point".
#
# As you step inside, you are immediately greeted by a somewhat panicked reindeer wearing goggles and a loose-fitting hard hat. The reindeer leads you to a shelf of goggles and hard hats (you quickly find some that fit) and then further into the facility. At one point, you pass a button with a faint snout mark and the label "PUSH FOR HELP". No wonder you were loaded into that trebuchet so quickly!
#
# You pass through a final set of doors surrounded with even more warning signs and into what must be the room that collects all of the light from outside. As you admire the large assortment of lenses available to further focus the light, the reindeer brings you a book titled "Initialization Manual".
#
# "Hello!", the book cheerfully begins, apparently unaware of the concerned reindeer reading over your shoulder. "This procedure will let you bring the Lava Production Facility online - all without burning or melting anything unintended!"
#
# "Before you begin, please be prepared to use the Holiday ASCII String Helper algorithm (appendix 1A)." You turn to appendix 1A. The reindeer leans closer with interest.
#
# The HASH algorithm is a way to turn any string of characters into a single number in the range 0 to 255. To run the HASH algorithm on a string, start with a current value of 0. Then, for each character in the string starting from the beginning:
#
# - Determine the ASCII code for the current character of the string.
# - Increase the current value by the ASCII code you just determined.
# - Set the current value to itself multiplied by 17.
# - Set the current value to the remainder of dividing itself by 256.
# After following these steps for each character in the string in order, the current value is the output of the HASH algorithm.
#
# So, to find the result of running the HASH algorithm on the string HASH:
#
# - The current value starts at 0.
# - The first character is H; its ASCII code is 72.
# - The current value increases to 72.
# - The current value is multiplied by 17 to become 1224.
# - The current value becomes 200 (the remainder of 1224 divided by 256).
# - The next character is A; its ASCII code is 65.
# - The current value increases to 265.
# - The current value is multiplied by 17 to become 4505.
# - The current value becomes 153 (the remainder of 4505 divided by 256).
# - The next character is S; its ASCII code is 83.
# - The current value increases to 236.
# - The current value is multiplied by 17 to become 4012.
# - The current value becomes 172 (the remainder of 4012 divided by 256).
# - The next character is H; its ASCII code is 72.
# - The current value increases to 244.
# - The current value is multiplied by 17 to become 4148.
# - The current value becomes 52 (the remainder of 4148 divided by 256).
# So, the result of running the HASH algorithm on the string HASH is 52.
#
# The initialization sequence (your puzzle input) is a comma-separated list of steps to start the Lava Production Facility. Ignore newline characters when parsing the initialization sequence. To verify that your HASH algorithm is working, the book offers the sum of the result of running the HASH algorithm on each step in the initialization sequence.
#
# For example:
#
# ```
# rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7
# ```
# This initialization sequence specifies 11 individual steps; the result of running the HASH algorithm on each of the steps is as follows:
#
# - rn=1 becomes 30.
# - cm- becomes 253.
# - qp=3 becomes 97.
# - cm=2 becomes 47.
# - qp- becomes 14.
# - pc=4 becomes 180.
# - ot=9 becomes 9.
# - ab=5 becomes 197.
# - pc- becomes 48.
# - pc=6 becomes 214.
# - ot=7 becomes 231.
# In this example, the sum of these results is 1320. Unfortunately, the reindeer has stolen the page containing the expected verification number and is currently running around the facility with it excitedly.
#
# Run the HASH algorithm on each step in the initialization sequence. What is the sum of the results? (The initialization sequence is one long line; be careful when copy-pasting it.)

# %%
def run_HASH(string: str) -> int:
    current_value = 0
    for char in string:
        # print(f'{char=}')
        current_value += ord(char)
        # print(f'1. {current_value=}')
        current_value *= 17
        # print(f'2. {current_value=}')
        current_value %= 256
        # print(f'3. {current_value=}')
    return current_value


run_HASH("HASH")
# Out:
# 52

# %%
test_input = """rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7"""
test_values = [run_HASH(string) for string in test_input.split(",")]
sum(test_values)
# Out:
# 1320

# %%
input_str = open("../inputs/15.txt").read()
values = [run_HASH(string) for string in input_str.split(",")]
sum(values)
# Out:
# 514394

# %% [markdown]
# You convince the reindeer to bring you the page; the page confirms that your HASH algorithm is working.
#
# The book goes on to describe a series of 256 boxes numbered 0 through 255. The boxes are arranged in a line starting from the point where light enters the facility. The boxes have holes that allow light to pass from one box to the next all the way down the line.
# ```
#       +-----+  +-----+         +-----+
# Light | Box |  | Box |   ...   | Box |
# ----------------------------------------->
#       |  0  |  |  1  |   ...   | 255 |
#       +-----+  +-----+         +-----+
# ```
# Inside each box, there are several lens slots that will keep a lens correctly positioned to focus light passing through the box. The side of each box has a panel that opens to allow you to insert or remove lenses as necessary.
#
# Along the wall running parallel to the boxes is a large library containing lenses organized by focal length ranging from 1 through 9. The reindeer also brings you a small handheld label printer.
#
# The book goes on to explain how to perform each step in the initialization sequence, a process it calls the Holiday ASCII String Helper Manual Arrangement Procedure, or HASHMAP for short.
#
# Each step begins with a sequence of letters that indicate the label of the lens on which the step operates. The result of running the HASH algorithm on the label indicates the correct box for that step.
#
# The label will be immediately followed by a character that indicates the operation to perform: either an equals sign (=) or a dash (-).
#
# If the operation character is a dash (-), go to the relevant box and remove the lens with the given label if it is present in the box. Then, move any remaining lenses as far forward in the box as they can go without changing their order, filling any space made by removing the indicated lens. (If no lens in that box has the given label, nothing happens.)
#
# If the operation character is an equals sign (=), it will be followed by a number indicating the focal length of the lens that needs to go into the relevant box; be sure to use the label maker to mark the lens with the label given in the beginning of the step so you can find it later. There are two possible situations:
#
# If there is already a lens in the box with the same label, replace the old lens with the new lens: remove the old lens and put the new lens in its place, not moving any other lenses in the box.
# If there is not already a lens in the box with the same label, add the lens to the box immediately behind any lenses already in the box. Don't move any of the other lenses when you do this. If there aren't any lenses in the box, the new lens goes all the way to the front of the box.
# Here is the contents of every box after each step in the example initialization sequence above:
# ```
# After "rn=1":
# Box 0: [rn 1]
#
# After "cm-":
# Box 0: [rn 1]
#
# After "qp=3":
# Box 0: [rn 1]
# Box 1: [qp 3]
#
# After "cm=2":
# Box 0: [rn 1] [cm 2]
# Box 1: [qp 3]
#
# After "qp-":
# Box 0: [rn 1] [cm 2]
#
# After "pc=4":
# Box 0: [rn 1] [cm 2]
# Box 3: [pc 4]
#
# After "ot=9":
# Box 0: [rn 1] [cm 2]
# Box 3: [pc 4] [ot 9]
#
# After "ab=5":
# Box 0: [rn 1] [cm 2]
# Box 3: [pc 4] [ot 9] [ab 5]
#
# After "pc-":
# Box 0: [rn 1] [cm 2]
# Box 3: [ot 9] [ab 5]
#
# After "pc=6":
# Box 0: [rn 1] [cm 2]
# Box 3: [ot 9] [ab 5] [pc 6]
#
# After "ot=7":
# Box 0: [rn 1] [cm 2]
# Box 3: [ot 7] [ab 5] [pc 6]
# ```
# All 256 boxes are always present; only the boxes that contain any lenses are shown here. Within each box, lenses are listed from front to back; each lens is shown as its label and focal length in square brackets.
#
# To confirm that all of the lenses are installed correctly, add up the focusing power of all of the lenses. The focusing power of a single lens is the result of multiplying together:
#
# - One plus the box number of the lens in question.
# - The slot number of the lens within the box: 1 for the first lens, 2 for the second lens, and so on.
# - The focal length of the lens.
# At the end of the above example, the focusing power of each lens is as follows:
#
# - rn: 1 (box 0) * 1 (first slot) * 1 (focal length) = 1
# - cm: 1 (box 0) * 2 (second slot) * 2 (focal length) = 4
# - ot: 4 (box 3) * 1 (first slot) * 7 (focal length) = 28
# - ab: 4 (box 3) * 2 (second slot) * 5 (focal length) = 40
# - pc: 4 (box 3) * 3 (third slot) * 6 (focal length) = 72
# So, the above example ends up with a total focusing power of 145.
#
# With the help of an over-enthusiastic reindeer in a hard hat, follow the initialization sequence. What is the focusing power of the resulting lens configuration?

# %%
def get_box_values(string: str) -> int:
    boxes = {}
    for label_str in string.split(","):
        # rn=1, cm-, qp=3, etc
        if "=" in label_str:
            # add/replace a label to a box
            label, focal_strength = label_str.split("=")
            box_num = run_HASH(label)
            if box_num not in boxes:
                boxes[box_num] = {}
            boxes[box_num][label] = focal_strength
        else:
            # remove a label from a box
            label = label_str.strip("-")
            box_num = run_HASH(label)
            boxes.get(box_num, {}).pop(label, None)

    print(boxes)

    values = []
    for box_num, label_data in boxes.items():
        for i, (label, focal_strength) in enumerate(label_data.items()):
            value = (int(box_num) + 1) * (i + 1) * int(focal_strength)
            print(
                f"{label} (box {box_num}) * {i+1} (slot) * {focal_strength} (focal strength) = {value}"
            )
            values.append(value)

    return sum(values)


get_box_values(test_input)
# Out:
# {0: {'rn': '1', 'cm': '2'}, 1: {}, 3: {'ot': '7', 'ab': '5', 'pc': '6'}}
# rn (box 0) * 1 (slot) * 1 (focal strength) = 1
# cm (box 0) * 2 (slot) * 2 (focal strength) = 4
# ot (box 3) * 1 (slot) * 7 (focal strength) = 28
# ab (box 3) * 2 (slot) * 5 (focal strength) = 40
# pc (box 3) * 3 (slot) * 6 (focal strength) = 72
# 145

# %%
get_box_values(input_str)
# Out:
# {6: {'hfx': '9', 'lz': '8', 'zgcr': '8'}, 94: {}, 89: {'mjgk': '8', 'sbt': '9'}, 158: {'zcq': '4'}, 82: {'rjv': '4'}, 238: {'hlz': '8'}, 75: {'jqp': '4'}, 221: {'xkhb': '2'}, 170: {'rx': '3', 'rfdn': '4'}, 60: {'jr': '1'}, 86: {'rcccsh': '8', 'dqqxh': '8'}, 120: {'hzv': '8'}, 92: {}, 41: {'bxgklq': '7', 'lm': '7'}, 39: {'kbj': '8'}, 252: {'xnv': '4', 'kjg': '8', 'vf': '7'}, 70: {'mznnc': '6'}, 132: {'rzx': '8', 'pksf': '2', 'thh': '9'}, 218: {'gc': '2'}, 61: {'jc': '6'}, 79: {'fgb': '9'}, 102: {}, 224: {}, 5: {'ng': '1', 'qfbl': '8'}, 228: {'rjtt': '4', 'xtx': '6', 'mg': '5', 'lx': '9'}, 56: {}, 171: {'vnfq': '3'}, 246: {'qcr': '7'}, 162: {'jx': '3'}, 156: {'cxjg': '9'}, 203: {'pmn': '3', 'tg': '3'}, 193: {'sjrr': '5', 'kbd': '2'}, 240: {}, 62: {}, 28: {'hbr': '9'}, 44: {'nszns': '1'}, 21: {'kcg': '6', 'bmrd': '6'}, 243: {}, 84: {'zxb': '9', 'dp': '3', 'zjxhp': '4'}, 131: {}, 80: {'sjs': '3', 'vz': '6', 'fsfgj': '3', 'hh': '8', 'pscz': '3'}, 168: {'gpq': '3', 'tgzqhz': '2'}, 255: {'sfv': '4', 'hjzc': '9'}, 93: {'zs': '4'}, 29: {}, 155: {'bgr': '6'}, 196: {'fxf': '4'}, 74: {'bnnl': '7'}, 153: {}, 77: {'zc': '8', 'mxx': '3', 'tkn': '9', 'js': '4'}, 18: {'hzp': '1'}, 36: {'rfl': '7', 'ctm': '9'}, 167: {'pfhdsr': '2'}, 32: {'tl': '6'}, 99: {}, 184: {'gqp': '2'}, 127: {'lc': '5', 'fxq': '9'}, 176: {'jdb': '4', 'nb': '5'}, 204: {'jhz': '8'}, 201: {'fzrg': '9'}, 88: {'srs': '1', 'tlrdb': '5'}, 128: {'zf': '8', 'qqn': '9', 'jv': '3'}, 225: {'nmf': '7'}, 169: {}, 230: {}, 24: {'ll': '7'}, 254: {'qzs': '7', 'dz': '4'}, 189: {'bgt': '3', 'bk': '4'}, 124: {'nks': '3'}, 31: {'gvgk': '1'}, 16: {'sm': '5', 'plt': '4'}, 152: {'dfvrf': '3'}, 154: {'rh': '9'}, 85: {}, 126: {}, 76: {'zr': '1', 'hzcct': '7'}, 137: {'htsz': '8', 'lfbxm': '9'}, 65: {'shv': '2'}, 58: {}, 212: {}, 209: {}, 47: {'tsvb': '2'}, 200: {}, 148: {}, 244: {}, 103: {'ldg': '6', 'vmhl': '5'}, 180: {'tzf': '9'}, 73: {'bpkl': '6', 'nk': '9'}, 237: {'xskpg': '1', 'xlvc': '6'}, 177: {'vsfr': '4'}, 71: {'pg': '3'}, 11: {'cll': '6', 'hs': '9', 'mhtb': '6'}, 206: {'fgbmr': '7', 'qm': '4', 'hssnb': '3', 'dsg': '8'}, 111: {}, 186: {'dfp': '5'}, 9: {'kmq': '8'}, 35: {}, 108: {'rbx': '4'}, 134: {}, 46: {}, 144: {'ld': '5'}, 20: {'fxpf': '9'}, 216: {}, 115: {'cxdvn': '6'}, 251: {'hjjbm': '9'}, 98: {'kjm': '1'}, 22: {'dpb': '6', 'zrgsmc': '2'}, 87: {}, 250: {'pbh': '9'}, 64: {'vj': '9', 'mfm': '4'}, 191: {'crz': '7', 'sdrlgs': '3', 'qfx': '6', 'gkm': '2'}, 2: {}, 13: {'gf': '4'}, 151: {'ts': '8'}, 23: {'cqc': '3'}, 96: {'vtv': '9', 'xh': '3'}, 106: {}, 105: {'qvr': '2'}, 205: {}, 236: {'tfr': '7'}, 160: {}, 10: {'rnxr': '3', 'vxxd': '4'}, 248: {'fhj': '9'}, 210: {}, 123: {'phs': '6'}, 7: {'brc': '7', 'lvvdch': '3', 'lmn': '5'}, 63: {}, 182: {'dxnl': '6'}, 234: {'gs': '1', 'vtzxn': '9'}, 129: {'dzs': '7', 'hkmzg': '3', 'zxvvs': '4'}, 227: {'mv': '4'}, 112: {'bnzf': '9', 'jf': '4'}, 12: {}, 34: {'rp': '3'}, 33: {'sfx': '3', 'sn': '9'}, 174: {'sch': '4'}, 49: {}, 222: {'zgm': '8', 'trx': '8', 'bxd': '1'}, 66: {}, 121: {'qh': '7', 'rchl': '1'}, 147: {'xk': '3'}, 163: {}, 150: {}, 1: {}, 38: {'nrxks': '3', 'nx': '6', 'fmc': '3'}, 26: {'hdn': '3', 'jp': '9', 'bmvkj': '8'}, 223: {'bm': '4'}, 233: {'smmfv': '1'}, 220: {}, 192: {'nr': '9'}, 133: {'cjh': '3'}, 239: {}, 241: {}, 90: {'vjz': '9'}, 232: {'xp': '2'}, 213: {'zk': '3'}, 173: {'ktxv': '5'}, 214: {}, 242: {'tfjn': '7'}, 161: {'kxprl': '5'}, 211: {'kph': '1'}, 164: {'zvpd': '8', 'fgg': '1'}, 194: {}, 107: {'mmq': '2', 'nm': '4'}, 116: {}, 67: {}, 187: {'sldvr': '8'}, 117: {}, 135: {'qzl': '9', 'tc': '3', 'hjzk': '3'}, 245: {}, 197: {'lkn': '8'}, 19: {'ps': '7'}, 145: {'lkz': '9'}, 141: {'gmrg': '8', 'dvnxlq': '8', 'zrq': '2'}, 249: {}, 72: {'hhx': '7', 'ccr': '7'}, 195: {'kx': '7'}, 109: {'jkkm': '7', 'fjm': '6'}, 183: {'vq': '2', 'kdpkm': '2'}, 45: {}, 140: {'zdn': '6', 'vgqks': '5'}, 104: {'tbr': '2'}, 100: {'mdxk': '8'}, 55: {}, 81: {'gj': '6'}, 219: {'xmv': '4'}, 8: {'bbd': '7'}, 175: {'rbhc': '5', 'qfh': '3'}, 190: {'pn': '5'}, 119: {}, ...
# hfx (box 6) * 1 (slot) * 9 (focal strength) = 63
# lz (box 6) * 2 (slot) * 8 (focal strength) = 112
# zgcr (box 6) * 3 (slot) * 8 (focal strength) = 168
# mjgk (box 89) * 1 (slot) * 8 (focal strength) = 720
# sbt (box 89) * 2 (slot) * 9 (focal strength) = 1620
# zcq (box 158) * 1 (slot) * 4 (focal strength) = 636
# rjv (box 82) * 1 (slot) * 4 (focal strength) = 332
# hlz (box 238) * 1 (slot) * 8 (focal strength) = 1912
# jqp (box 75) * 1 (slot) * 4 (focal strength) = 304
# xkhb (box 221) * 1 (slot) * 2 (focal strength) = 444
# rx (box 170) * 1 (slot) * 3 (focal strength) = 513
# rfdn (box 170) * 2 (slot) * 4 (focal strength) = 1368
# jr (box 60) * 1 (slot) * 1 (focal strength) = 61
# rcccsh (box 86) * 1 (slot) * 8 (focal strength) = 696
# dqqxh (box 86) * 2 (slot) * 8 (focal strength) = 1392
# hzv (box 120) * 1 (slot) * 8 (focal strength) = 968
# bxgklq (box 41) * 1 (slot) * 7 (focal strength) = 294
# lm (box 41) * 2 (slot) * 7 (focal strength) = 588
# kbj (box 39) * 1 (slot) * 8 (focal strength) = 320
# xnv (box 252) * 1 (slot) * 4 (focal strength) = 1012
# kjg (box 252) * 2 (slot) * 8 (focal strength) = 4048
# vf (box 252) * 3 (slot) * 7 (focal strength) = 5313
# mznnc (box 70) * 1 (slot) * 6 (focal strength) = 426
# rzx (box 132) * 1 (slot) * 8 (focal strength) = 1064
# pksf (box 132) * 2 (slot) * 2 (focal strength) = 532
# thh (box 132) * 3 (slot) * 9 (focal strength) = 3591
# gc (box 218) * 1 (slot) * 2 (focal strength) = 438
# jc (box 61) * 1 (slot) * 6 (focal strength) = 372
# fgb (box 79) * 1 (slot) * 9 (focal strength) = 720
# ng (box 5) * 1 (slot) * 1 (focal strength) = 6
# qfbl (box 5) * 2 (slot) * 8 (focal strength) = 96
# rjtt (box 228) * 1 (slot) * 4 (focal strength) = 916
# xtx (box 228) * 2 (slot) * 6 (focal strength) = 2748
# mg (box 228) * 3 (slot) * 5 (focal strength) = 3435
# lx (box 228) * 4 (slot) * 9 (focal strength) = 8244
# vnfq (box 171) * 1 (slot) * 3 (focal strength) = 516
# qcr (box 246) * 1 (slot) * 7 (focal strength) = 1729
# jx (box 162) * 1 (slot) * 3 (focal strength) = 489
# cxjg (box 156) * 1 (slot) * 9 (focal strength) = 1413
# pmn (box 203) * 1 (slot) * 3 (focal strength) = 612
# tg (box 203) * 2 (slot) * 3 (focal strength) = 1224
# sjrr (box 193) * 1 (slot) * 5 (focal strength) = 970
# kbd (box 193) * 2 (slot) * 2 (focal strength) = 776
# hbr (box 28) * 1 (slot) * 9 (focal strength) = 261
# nszns (box 44) * 1 (slot) * 1 (focal strength) = 45
# kcg (box 21) * 1 (slot) * 6 (focal strength) = 132
# bmrd (box 21) * 2 (slot) * 6 (focal strength) = 264
# zxb (box 84) * 1 (slot) * 9 (focal strength) = 765
# dp (box 84) * 2 (slot) * 3 (focal strength) = 510
# zjxhp (box 84) * 3 (slot) * 4 (focal strength) = 1020
# sjs (box 80) * 1 (slot) * 3 (focal strength) = 243
# vz (box 80) * 2 (slot) * 6 (focal strength) = 972
# fsfgj (box 80) * 3 (slot) * 3 (focal strength) = 729
# hh (box 80) * 4 (slot) * 8 (focal strength) = 2592
# pscz (box 80) * 5 (slot) * 3 (focal strength) = 1215
# gpq (box 168) * 1 (slot) * 3 (focal strength) = 507
# tgzqhz (box 168) * 2 (slot) * 2 (focal strength) = 676
# sfv (box 255) * 1 (slot) * 4 (focal strength) = 1024
# hjzc (box 255) * 2 (slot) * 9 (focal strength) = 4608
# zs (box 93) * 1 (slot) * 4 (focal strength) = 376
# bgr (box 155) * 1 (slot) * 6 (focal strength) = 936
# fxf (box 196) * 1 (slot) * 4 (focal strength) = 788
# bnnl (box 74) * 1 (slot) * 7 (focal strength) = 525
# zc (box 77) * 1 (slot) * 8 (focal strength) = 624
# mxx (box 77) * 2 (slot) * 3 (focal strength) = 468
# tkn (box 77) * 3 (slot) * 9 (focal strength) = 2106
# js (box 77) * 4 (slot) * 4 (focal strength) = 1248
# hzp (box 18) * 1 (slot) * 1 (focal strength) = 19
# rfl (box 36) * 1 (slot) * 7 (focal strength) = 259
# ctm (box 36) * 2 (slot) * 9 (focal strength) = 666
# pfhdsr (box 167) * 1 (slot) * 2 (focal strength) = 336
# tl (box 32) * 1 (slot) * 6 (focal strength) = 198
# gqp (box 184) * 1 (slot) * 2 (focal strength) = 370
# lc (box 127) * 1 (slot) * 5 (focal strength) = 640
# fxq (box 127) * 2 (slot) * 9 (focal strength) = 2304
# jdb (box 176) * 1 (slot) * 4 (focal strength) = 708
# nb (box 176) * 2 (slot) * 5 (focal strength) = 1770
# jhz (box 204) * 1 (slot) * 8 (focal strength) = 1640
# fzrg (box 201) * 1 (slot) * 9 (focal strength) = 1818
# srs (box 88) * 1 (slot) * 1 (focal strength) = 89
# tlrdb (box 88) * 2 (slot) * 5 (focal strength) = 890
# zf (box 128) * 1 (slot) * 8 (focal strength) = 1032
# qqn (box 128) * 2 (slot) * 9 (focal strength) = 2322
# jv (box 128) * 3 (slot) * 3 (focal strength) = 1161
# nmf (box 225) * 1 (slot) * 7 (focal strength) = 1582
# ll (box 24) * 1 (slot) * 7 (focal strength) = 175
# qzs (box 254) * 1 (slot) * 7 (focal strength) = 1785
# dz (box 254) * 2 (slot) * 4 (focal strength) = 2040
# bgt (box 189) * 1 (slot) * 3 (focal strength) = 570
# bk (box 189) * 2 (slot) * 4 (focal strength) = 1520
# nks (box 124) * 1 (slot) * 3 (focal strength) = 375
# gvgk (box 31) * 1 (slot) * 1 (focal strength) = 32
# sm (box 16) * 1 (slot) * 5 (focal strength) = 85
# plt (box 16) * 2 (slot) * 4 (focal strength) = 136
# dfvrf (box 152) * 1 (slot) * 3 (focal strength) = 459
# rh (box 154) * 1 (slot) * 9 (focal strength) = 1395
# zr (box 76) * 1 (slot) * 1 (focal strength) = 77
# hzcct (box 76) * 2 (slot) * 7 (focal strength) = 1078
# htsz (box 137) * 1 (slot) * 8 (focal strength) = 1104
# lfbxm (box 137) * 2 (slot) * 9 (focal strength) = 2484
# shv (box 65) * 1 (slot) * 2 (focal strength) = 132
# tsvb (box 47) * 1 (slot) * 2 (focal strength) = 96
# ldg (box 103) * 1 (slot) * 6 (focal strength) = 624
# vmhl (box 103) * 2 (slot) * 5 (focal strength) = 1040
# tzf (box 180) * 1 (slot) * 9 (focal strength) = 1629
# bpkl (box 73) * 1 (slot) * 6 (focal strength) = 444
# nk (box 73) * 2 (slot) * 9 (focal strength) = 1332
# xskpg (box 237) * 1 (slot) * 1 (focal strength) = 238
# xlvc (box 237) * 2 (slot) * 6 (focal strength) = 2856
# vsfr (box 177) * 1 (slot) * 4 (focal strength) = 712
# pg (box 71) * 1 (slot) * 3 (focal strength) = 216
# cll (box 11) * 1 (slot) * 6 (focal strength) = 72
# hs (box 11) * 2 (slot) * 9 (focal strength) = 216
# mhtb (box 11) * 3 (slot) * 6 (focal strength) = 216
# fgbmr (box 206) * 1 (slot) * 7 (focal strength) = 1449
# qm (box 206) * 2 (slot) * 4 (focal strength) = 1656
# hssnb (box 206) * 3 (slot) * 3 (focal strength) = 1863
# dsg (box 206) * 4 (slot) * 8 (focal strength) = 6624
# dfp (box 186) * 1 (slot) * 5 (focal strength) = 935
# kmq (box 9) * 1 (slot) * 8 (focal strength) = 80
# rbx (box 108) * 1 (slot) * 4 (focal strength) = 436
# ld (box 144) * 1 (slot) * 5 (focal strength) = 725
# fxpf (box 20) * 1 (slot) * 9 (focal strength) = 189
# cxdvn (box 115) * 1 (slot) * 6 (focal strength) = 696
# hjjbm (box 251) * 1 (slot) * 9 (focal strength) = 2268
# kjm (box 98) * 1 (slot) * 1 (focal strength) = 99
# dpb (box 22) * 1 (slot) * 6 (focal strength) = 138
# zrgsmc (box 22) * 2 (slot) * 2 (focal strength) = 92
# pbh (box 250) * 1 (slot) * 9 (focal strength) = 2259
# vj (box 64) * 1 (slot) * 9 (focal strength) = 585
# mfm (box 64) * 2 (slot) * 4 (focal strength) = 520
# crz (box 191) * 1 (slot) * 7 (focal strength) = 1344
# sdrlgs (box 191) * 2 (slot) * 3 (focal strength) = 1152
# qfx (box 191) * 3 (slot) * 6 (focal strength) = 3456
# gkm (box 191) * 4 (slot) * 2 (focal strength) = 1536
# gf (box 13) * 1 (slot) * 4 (focal strength) = 56
# ts (box 151) * 1 (slot) * 8 (focal strength) = 1216
# cqc (box 23) * 1 (slot) * 3 (focal strength) = 72
# vtv (box 96) * 1 (slot) * 9 (focal strength) = 873
# xh (box 96) * 2 (slot) * 3 (focal strength) = 582
# qvr (box 105) * 1 (slot) * 2 (focal strength) = 212
# tfr (box 236) * 1 (slot) * 7 (focal strength) = 1659
# rnxr (box 10) * 1 (slot) * 3 (focal strength) = 33
# vxxd (box 10) * 2 (slot) * 4 (focal strength) = 88
# fhj (box 248) * 1 (slot) * 9 (focal strength) = 2241
# phs (box 123) * 1 (slot) * 6 (focal strength) = 744
# brc (box 7) * 1 (slot) * 7 (focal strength) = 56
# lvvdch (box 7) * 2 (slot) * 3 (focal strength) = 48
# lmn (box 7) * 3 (slot) * 5 (focal strength) = 120
# dxnl (box 182) * 1 (slot) * 6 (focal strength) = 1098
# gs (box 234) * 1 (slot) * 1 (focal strength) = 235
# vtzxn (box 234) * 2 (slot) * 9 (focal strength) = 4230
# dzs (box 129) * 1 (slot) * 7 (focal strength) = 910
# hkmzg (box 129) * 2 (slot) * 3 (focal strength) = 780
# zxvvs (box 129) * 3 (slot) * 4 (focal strength) = 1560
# mv (box 227) * 1 (slot) * 4 (focal strength) = 912
# bnzf (box 112) * 1 (slot) * 9 (focal strength) = 1017
# jf (box 112) * 2 (slot) * 4 (focal strength) = 904
# rp (box 34) * 1 (slot) * 3 (focal strength) = 105
# sfx (box 33) * 1 (slot) * 3 (focal strength) = 102
# sn (box 33) * 2 (slot) * 9 (focal strength) = 612
# sch (box 174) * 1 (slot) * 4 (focal strength) = 700
# zgm (box 222) * 1 (slot) * 8 (focal strength) = 1784
# trx (box 222) * 2 (slot) * 8 (focal strength) = 3568
# bxd (box 222) * 3 (slot) * 1 (focal strength) = 669
# qh (box 121) * 1 (slot) * 7 (focal strength) = 854
# rchl (box 121) * 2 (slot) * 1 (focal strength) = 244
# xk (box 147) * 1 (slot) * 3 (focal strength) = 444
# nrxks (box 38) * 1 (slot) * 3 (focal strength) = 117
# nx (box 38) * 2 (slot) * 6 (focal strength) = 468
# fmc (box 38) * 3 (slot) * 3 (focal strength) = 351
# hdn (box 26) * 1 (slot) * 3 (focal strength) = 81
# jp (box 26) * 2 (slot) * 9 (focal strength) = 486
# bmvkj (box 26) * 3 (slot) * 8 (focal strength) = 648
# bm (box 223) * 1 (slot) * 4 (focal strength) = 896
# smmfv (box 233) * 1 (slot) * 1 (focal strength) = 234
# nr (box 192) * 1 (slot) * 9 (focal strength) = 1737
# cjh (box 133) * 1 (slot) * 3 (focal strength) = 402
# vjz (box 90) * 1 (slot) * 9 (focal strength) = 819
# xp (box 232) * 1 (slot) * 2 (focal strength) = 466
# zk (box 213) * 1 (slot) * 3 (focal strength) = 642
# ktxv (box 173) * 1 (slot) * 5 (focal strength) = 870
# tfjn (box 242) * 1 (slot) * 7 (focal strength) = 1701
# kxprl (box 161) * 1 (slot) * 5 (focal strength) = 810
# kph (box 211) * 1 (slot) * 1 (focal strength) = 212
# zvpd (box 164) * 1 (slot) * 8 (focal strength) = 1320
# fgg (box 164) * 2 (slot) * 1 (focal strength) = 330
# mmq (box 107) * 1 (slot) * 2 (focal strength) = 216
# nm (box 107) * 2 (slot) * 4 (focal strength) = 864
# sldvr (box 187) * 1 (slot) * 8 (focal strength) = 1504
# qzl (box 135) * 1 (slot) * 9 (focal strength) = 1224
# tc (box 135) * 2 (slot) * 3 (focal strength) = 816
# hjzk (box 135) * 3 (slot) * 3 (focal strength) = 1224
# lkn (box 197) * 1 (slot) * 8 (focal strength) = 1584
# ps (box 19) * 1 (slot) * 7 (focal strength) = 140
# lkz (box 145) * 1 (slot) * 9 (focal strength) = 1314
# gmrg (box 141) * 1 (slot) * 8 (focal strength) = 1136
# dvnxlq (box 141) * 2 (slot) * 8 (focal strength) = 2272
# zrq (box 141) * 3 (slot) * 2 (focal strength) = 852
# hhx (box 72) * 1 (slot) * 7 (focal strength) = 511
# ccr (box 72) * 2 (slot) * 7 (focal strength) = 1022
# kx (box 195) * 1 (slot) * 7 (focal strength) = 1372
# jkkm (box 109) * 1 (slot) * 7 (focal strength) = 770
# fjm (box 109) * 2 (slot) * 6 (focal strength) = 1320
# vq (box 183) * 1 (slot) * 2 (focal strength) = 368
# kdpkm (box 183) * 2 (slot) * 2 (focal strength) = 736
# zdn (box 140) * 1 (slot) * 6 (focal strength) = 846
# vgqks (box 140) * 2 (slot) * 5 (focal strength) = 1410
# tbr (box 104) * 1 (slot) * 2 (focal strength) = 210
# mdxk (box 100) * 1 (slot) * 8 (focal strength) = 808
# gj (box 81) * 1 (slot) * 6 (focal strength) = 492
# xmv (box 219) * 1 (slot) * 4 (focal strength) = 880
# bbd (box 8) * 1 (slot) * 7 (focal strength) = 63
# rbhc (box 175) * 1 (slot) * 5 (focal strength) = 880
# qfh (box 175) * 2 (slot) * 3 (focal strength) = 1056
# pn (box 190) * 1 (slot) * 5 (focal strength) = 955
# ls (box 143) * 1 (slot) * 7 (focal strength) = 1008
# zx (box 178) * 1 (slot) * 5 (focal strength) = 895
# bdh (box 142) * 1 (slot) * 9 (focal strength) = 1287
# hll (box 0) * 1 (slot) * 9 (focal strength) = 9
# zq (box 59) * 1 (slot) * 8 (focal strength) = 480
# smg (box 231) * 1 (slot) * 4 (focal strength) = 928
# jq (box 43) * 1 (slot) * 8 (focal strength) = 352
# vsqnvg (box 229) * 1 (slot) * 3 (focal strength) = 690
# xjh (box 138) * 1 (slot) * 7 (focal strength) = 973
# qbmj (box 138) * 2 (slot) * 5 (focal strength) = 1390
# sbckcf (box 188) * 1 (slot) * 7 (focal strength) = 1323
# bz (box 188) * 2 (slot) * 9 (focal strength) = 3402
# llv (box 110) * 1 (slot) * 9 (focal strength) = 999
# fbm (box 101) * 1 (slot) * 1 (focal strength) = 102
# nmcg (box 101) * 2 (slot) * 8 (focal strength) = 1632
# cp (box 51) * 1 (slot) * 3 (focal strength) = 156
# mfv (box 217) * 1 (slot) * 3 (focal strength) = 654
# kgb (box 68) * 1 (slot) * 9 (focal strength) = 621
# xnd (box 202) * 1 (slot) * 5 (focal strength) = 1015
# fg (box 253) * 1 (slot) * 9 (focal strength) = 2286
# hlfg (box 17) * 1 (slot) * 3 (focal strength) = 54
# cn (box 17) * 2 (slot) * 9 (focal strength) = 324
# bs (box 69) * 1 (slot) * 4 (focal strength) = 280
# lqkl (box 4) * 1 (slot) * 7 (focal strength) = 35
# plz (box 118) * 1 (slot) * 4 (focal strength) = 476
# bc (box 53) * 1 (slot) * 7 (focal strength) = 378
# jmkgv (box 207) * 1 (slot) * 1 (focal strength) = 208
# hm (box 165) * 1 (slot) * 2 (focal strength) = 332
# xn (box 198) * 1 (slot) * 5 (focal strength) = 995
# srn (box 3) * 1 (slot) * 8 (focal strength) = 32
# 236358
